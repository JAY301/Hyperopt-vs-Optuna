# %%
import os
os.environ['PYTHONHASHSEED']=str(0)
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""
import random
random.seed(0)
import numpy as np
np.random.seed(0)
import tensorflow as tf
tf.compat.v1.set_random_seed(0)
import matplotlib.pyplot as plt
from keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
from keras.optimizers import adam, SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.applications import ResNet50
from keras.utils import to_categorical
import csv
import pickle
cifar_image_path = 'cifar-10-batches-py'


#list of hyperparameters
# 1. learning rate
# 2. no of layers
# 3. optimization method
# 4. no of hidden units
# 5. dropout rate

#for testing purpose, only 1 and 5 selected
# Out:
# Using TensorFlow backend.

# %%
import optuna
from optuna.integration import KerasPruningCallback
tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(tf.config.experimental.list_logical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#function to load cifar-10 image-file (batch wise)
def load_cifar10_data(cifar_image_path, n_batch):
    
    features = []
    labels = []
    
    for batch_id in range(1, n_batch + 1):
        #'with open()'- opens the file 
        #f = open("path_to_file", mode='r+b') in reading + binary mode
        with open(cifar_image_path + '/data_batch_' + str(batch_id), mode='r+b') as file:
        
        
            #Module translates an in-memory Python object  
            #into a serialized byte stream—a string of  
            #bytes that can be written to any file-like object.
            #pickle.load - with filename
            #pickle.loads - without filename
            batch = pickle.load(file, encoding='latin1')
     
    
        for i in range(0, len(batch['labels'])):
        
            features.append(batch['data'][i])
            labels.append(batch['labels'][i])
    
    
    #divide the row vector (3072) into 3 pieces. Each piece corresponds to the each channels.
    #this results in (3 x 1024) dimension of tensor.
    #divide the resulting tensor from the previous step with 32. 32 here means width of an image.
    #this results in (3 x 32 x 32)    
    features = np.array(features)
    labels = np.array(labels)
    features = features.reshape((len(features), 3, 32, 32)).transpose(0, 2, 3, 1)
    
    
    #output is two arrays, first: feature matrix & second: label matrix
    return features, labels





#function to load cifar-10 test image-file
def load_cifar10_test_data(cifar_image_path):
    
    features = []
    labels = []
    
    with open(cifar_image_path + '/test_batch', mode='r+b') as file:
        
        batch = pickle.load(file, encoding='latin1')
     
    for i in range(0, len(batch['labels'])):
        
        features.append(batch['data'][i])
        labels.append(batch['labels'][i])
       
    features = np.array(features)
    labels = np.array(labels)
    features = features.reshape((len(features), 3, 32, 32)).transpose(0, 2, 3, 1)
    
    return features, labels

# %%
#loading images stored in 5 batches
features, labels = load_cifar10_data(cifar_image_path, 5)

print('Shape of feature-matrix containing image-data is given below (no. of images x image-dims) :')
print(features.shape)
plt.imshow(features[545])
print(labels[545])

features = []
labels = []
# Out:
# Shape of feature-matrix containing image-data is given below (no. of images x image-dims) :
# (50000, 32, 32, 3)
# 7

# %%
#function to define desired lables to assign images in the dataset
def load_label_names():
    
    #returns array of strings for each class-name
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def create_model(trial):
    # dropout in each layer

    model = Sequential()   
    model.add(
        Conv2D(
            filters=trial.suggest_categorical("filters", [32, 64]),
            kernel_size= (3,3),
            padding = 'same',
            activation= 'relu',
            input_shape=(32,32,3),
            )
        )  
    n_cnn = trial.suggest_int("n_cnn", 1, 3)
    def conv(n_cnn):
        i = n_cnn
        if i > 0:
            num_filters1 = trial.suggest_categorical("n_filters_1".format(i), [32, 64])
            model.add(
                Conv2D(
                filters=num_filters1,
                kernel_size= (3,3),
                padding = 'same',
                activation= 'relu'
                )
            )
            if i > 1:
                num_filters2 = trial.suggest_categorical("n_filters_2".format(i), [64, 128])
                model.add(
                    Conv2D(
                    filters=num_filters2,
                    kernel_size= (3,3),
                    padding = 'same',
                    activation= 'relu'
                    )
                )
                if i > 2:
                    num_filters3 = trial.suggest_categorical("n_filters_3".format(i), [64, 128])
                    model.add(
                        Conv2D(
                        filters=num_filters3,
                        kernel_size= (3,3),
                        padding = 'same',
                        activation= 'relu'
                        )
                    )
                    
    conv(n_cnn)
    model.add(MaxPooling2D(pool_size=(2,2)))   
    model.add(Flatten())
    
    n_layers = trial.suggest_int("n_layers", 1, 3)
            
    if n_layers > 0:
        num_hidden1 = trial.suggest_categorical("n_units_1", [128, 256, 512, 1024, 2048])
        model.add(Dense(num_hidden1, activation="relu"))
        dropout1 = trial.suggest_uniform("dropout_1", 0.1, 0.3)
        model.add(Dropout(rate=dropout1))
        if n_layers > 1:
            num_hidden2 = trial.suggest_categorical("n_units_2", [128, 256, 512, 1024, 2048])
            model.add(Dense(num_hidden2, activation="relu"))
            dropout2 = trial.suggest_uniform("dropout_2", 0.1, 0.3)
            model.add(Dropout(rate=dropout2))
            if n_layers > 2:
                num_hidden3 = trial.suggest_categorical("n_units_3", [128, 256, 512, 1024, 2048])
                model.add(Dense(num_hidden3, activation="relu"))
                dropout3 = trial.suggest_uniform("dropout_3", 0.1, 0.3)
                model.add(Dropout(rate=dropout3))
    
    model.add(Dense(10, activation="softmax"))

    lr = trial.suggest_loguniform("lr", 1e-5, 1e-2)    
    
    opt = SGD(lr = lr)
    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()

    return model

# %%
def objective(trial):
    
    # clear clutter from previous session graphs.
    tf.keras.backend.clear_session()
    
    training_images, training_labels = load_cifar10_data(cifar_image_path, 5)
    training_images = training_images/255.0
    
    test_images, test_labels = load_cifar10_test_data(cifar_image_path)
    test_images = test_images/255.0

    print('Not using data augmentation.')
    
    # Generate our trial model.
    model = create_model(trial)
    
    # Fit the model on the training data.
    # The KerasPruningCallback checks for pruning condition every epoch.
    history = model.fit(training_images, training_labels, 
              callbacks=[KerasPruningCallback(trial, "val_acc")],
              epochs=15,
              validation_split = 0.1, verbose = 2)
    

    # Evaluate the model accuracy on the test set.
    score = model.evaluate(test_images, test_labels, verbose=0)
    print ('Test loss: {}, Test accuracy: {}'.format(score[0], score[1]*100.0))
    return score[1]

# %%
sampler = optuna.integration.CmaEsSampler()
study = optuna.create_study(sampler = sampler, direction="maximize", pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=50)
pruned_trials = [t for t in study.trials if t.state == optuna.structs.TrialState.PRUNED]
complete_trials = [t for t in study.trials if t.state == optuna.structs.TrialState.COMPLETE]
print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              1050624
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 5,276,074
# Trainable params: 5,276,074
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 9s - loss: 2.2926 - accuracy: 0.1143 - val_loss: 2.2773 - val_accuracy: 0.1150
# Epoch 2/15
#  - 7s - loss: 2.2587 - accuracy: 0.1494 - val_loss: 2.2181 - val_accuracy: 0.1804
# Epoch 3/15
#  - 7s - loss: 2.1649 - accuracy: 0.2194 - val_loss: 2.0771 - val_accuracy: 0.2744
# Epoch 4/15
#  - 7s - loss: 2.0328 - accuracy: 0.2720 - val_loss: 1.9656 - val_accuracy: 0.3024
# Epoch 5/15
#  - 7s - loss: 1.9488 - accuracy: 0.3011 - val_loss: 1.9058 - val_accuracy: 0.3212
# Epoch 6/15
#  - 7s - loss: 1.9007 - accuracy: 0.3216 - val_loss: 1.8685 - val_accuracy: 0.3432
# Epoch 7/15
#  - 7s - loss: 1.8584 - accuracy: 0.3397 - val_loss: 1.8300 - val_accuracy: 0.3522
# Epoch 8/15
#  - 7s - loss: 1.8196 - accuracy: 0.3549 - val_loss: 1.7901 - val_accuracy: 0.3688
# Epoch 9/15
#  - 7s - loss: 1.7859 - accuracy: 0.3682 - val_loss: 1.7551 - val_accuracy: 0.3838
# Epoch 10/15
#  - 7s - loss: 1.7504 - accuracy: 0.3798 - val_loss: 1.7265 - val_accuracy: 0.3916
# Epoch 11/15
#  - 7s - loss: 1.7200 - accuracy: 0.3911 - val_loss: 1.6873 - val_accuracy: 0.4038
# Epoch 12/15
#  - 7s - loss: 1.6875 - accuracy: 0.4003 - val_loss: 1.6744 - val_accuracy: 0.4174
# Epoch 13/15
#  - 7s - loss: 1.6616 - accuracy: 0.4114 - val_loss: 1.6552 - val_accuracy: 0.4132
# Epoch 14/15
#  - 8s - loss: 1.6348 - accuracy: 0.4212 - val_loss: 1.6343 - val_accuracy: 0.4244
# Epoch 15/15
#  - 7s - loss: 1.6098 - accuracy: 0.4290 - val_loss: 1.6226 - val_accuracy: 0.4230
# Test loss: 1.5936769317626953, Test accuracy: 43.57999861240387
# [I 2020-05-03 23:48:29,658] Finished trial#0 resulted in value: 0.4357999861240387. Current best value is 0.4357999861240387 with parameters: {'filters': 32, 'n_cnn': 1, 'n_filters_1': 32, 'n_layers': 2, 'n_units_1': 512, 'dropout_1': 0.12982276933564924, 'n_units_2': 2048, 'dropout_2': 0.2354621874476607, 'lr': 0.0007328007289354233}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              132096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,455,914
# Trainable params: 1,455,914
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 8s - loss: 2.3025 - accuracy: 0.1090 - val_loss: 2.2997 - val_accuracy: 0.1404
# Epoch 2/15
#  - 7s - loss: 2.3001 - accuracy: 0.1148 - val_loss: 2.2975 - val_accuracy: 0.1370
# Epoch 3/15
#  - 7s - loss: 2.2989 - accuracy: 0.1160 - val_loss: 2.2956 - val_accuracy: 0.1378
# Epoch 4/15
#  - 7s - loss: 2.2977 - accuracy: 0.1182 - val_loss: 2.2939 - val_accuracy: 0.1380
# Epoch 5/15
#  - 7s - loss: 2.2965 - accuracy: 0.1222 - val_loss: 2.2924 - val_accuracy: 0.1360
# Epoch 6/15
#  - 7s - loss: 2.2953 - accuracy: 0.1214 - val_loss: 2.2908 - val_accuracy: 0.1366
# Epoch 7/15
#  - 7s - loss: 2.2936 - accuracy: 0.1226 - val_loss: 2.2892 - val_accuracy: 0.1376
# Epoch 8/15
#  - 7s - loss: 2.2921 - accuracy: 0.1225 - val_loss: 2.2876 - val_accuracy: 0.1370
# Epoch 9/15
#  - 7s - loss: 2.2909 - accuracy: 0.1251 - val_loss: 2.2859 - val_accuracy: 0.1388
# Epoch 10/15
#  - 7s - loss: 2.2901 - accuracy: 0.1261 - val_loss: 2.2842 - val_accuracy: 0.1398
# Epoch 11/15
#  - 7s - loss: 2.2883 - accuracy: 0.1281 - val_loss: 2.2823 - val_accuracy: 0.1406
# Epoch 12/15
#  - 7s - loss: 2.2869 - accuracy: 0.1298 - val_loss: 2.2803 - val_accuracy: 0.1430
# Epoch 13/15
#  - 7s - loss: 2.2856 - accuracy: 0.1275 - val_loss: 2.2782 - val_accuracy: 0.1448
# Epoch 14/15
#  - 7s - loss: 2.2843 - accuracy: 0.1286 - val_loss: 2.2759 - val_accuracy: 0.1466
# Epoch 15/15
#  - 8s - loss: 2.2819 - accuracy: 0.1317 - val_loss: 2.2735 - val_accuracy: 0.1518
# Test loss: 2.275142478942871, Test accuracy: 14.900000393390656
# [I 2020-05-03 23:50:20,292] Finished trial#1 resulted in value: 0.14900000393390656. Current best value is 0.4357999861240387 with parameters: {'filters': 32, 'n_cnn': 1, 'n_filters_1': 32, 'n_layers': 2, 'n_units_1': 512, 'dropout_1': 0.12982276933564924, 'n_units_2': 2048, 'dropout_2': 0.2354621874476607, 'lr': 0.0007328007289354233}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 8,504,362
# Trainable params: 8,504,362
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 10s - loss: 2.0615 - accuracy: 0.2470 - val_loss: 1.8328 - val_accuracy: 0.3448
# Epoch 2/15
#  - 10s - loss: 1.7915 - accuracy: 0.3607 - val_loss: 1.6872 - val_accuracy: 0.3960
# Epoch 3/15
#  - 10s - loss: 1.6507 - accuracy: 0.4099 - val_loss: 1.5220 - val_accuracy: 0.4574
# Epoch 4/15
#  - 10s - loss: 1.5341 - accuracy: 0.4506 - val_loss: 1.5379 - val_accuracy: 0.4546
# Epoch 5/15
#  - 10s - loss: 1.4331 - accuracy: 0.4857 - val_loss: 1.4691 - val_accuracy: 0.4842
# Epoch 6/15
#  - 10s - loss: 1.3481 - accuracy: 0.5137 - val_loss: 1.3002 - val_accuracy: 0.5354
# Epoch 7/15
#  - 10s - loss: 1.2791 - accuracy: 0.5422 - val_loss: 1.2169 - val_accuracy: 0.5726
# Epoch 8/15
#  - 10s - loss: 1.2143 - accuracy: 0.5671 - val_loss: 1.3104 - val_accuracy: 0.5474
# Epoch 9/15
#  - 10s - loss: 1.1575 - accuracy: 0.5848 - val_loss: 1.1841 - val_accuracy: 0.5824
# Epoch 10/15
#  - 10s - loss: 1.0958 - accuracy: 0.6072 - val_loss: 1.0984 - val_accuracy: 0.6136
# Epoch 11/15
#  - 10s - loss: 1.0447 - accuracy: 0.6287 - val_loss: 1.0527 - val_accuracy: 0.6286
# Epoch 12/15
#  - 10s - loss: 0.9885 - accuracy: 0.6477 - val_loss: 1.0071 - val_accuracy: 0.6450
# Epoch 13/15
#  - 10s - loss: 0.9296 - accuracy: 0.6685 - val_loss: 1.0368 - val_accuracy: 0.6346
# Epoch 14/15
#  - 10s - loss: 0.8807 - accuracy: 0.6881 - val_loss: 1.0388 - val_accuracy: 0.6420
# Epoch 15/15
#  - 11s - loss: 0.8238 - accuracy: 0.7046 - val_loss: 0.9878 - val_accuracy: 0.6552
# Test loss: 1.016237229347229, Test accuracy: 64.52000141143799
# [I 2020-05-03 23:52:56,239] Finished trial#2 resulted in value: 0.6452000141143799. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 2,151,850
# Trainable params: 2,151,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 7s - loss: 2.3086 - accuracy: 0.1033 - val_loss: 2.3039 - val_accuracy: 0.1122
# Epoch 2/15
#  - 7s - loss: 2.3074 - accuracy: 0.1076 - val_loss: 2.3023 - val_accuracy: 0.1136
# Epoch 3/15
#  - 7s - loss: 2.3058 - accuracy: 0.1068 - val_loss: 2.3008 - val_accuracy: 0.1174
# Epoch 4/15
#  - 7s - loss: 2.3038 - accuracy: 0.1069 - val_loss: 2.2995 - val_accuracy: 0.1156
# Epoch 5/15
#  - 7s - loss: 2.3020 - accuracy: 0.1117 - val_loss: 2.2983 - val_accuracy: 0.1160
# Epoch 6/15
#  - 7s - loss: 2.3015 - accuracy: 0.1109 - val_loss: 2.2972 - val_accuracy: 0.1190
# Epoch 7/15
#  - 8s - loss: 2.2994 - accuracy: 0.1130 - val_loss: 2.2961 - val_accuracy: 0.1198
# Epoch 8/15
#  - 7s - loss: 2.2983 - accuracy: 0.1132 - val_loss: 2.2951 - val_accuracy: 0.1202
# Epoch 9/15
#  - 7s - loss: 2.2977 - accuracy: 0.1149 - val_loss: 2.2941 - val_accuracy: 0.1218
# Epoch 10/15
#  - 7s - loss: 2.2972 - accuracy: 0.1161 - val_loss: 2.2932 - val_accuracy: 0.1238
# Epoch 11/15
#  - 8s - loss: 2.2962 - accuracy: 0.1176 - val_loss: 2.2922 - val_accuracy: 0.1272
# Epoch 12/15
#  - 7s - loss: 2.2949 - accuracy: 0.1191 - val_loss: 2.2914 - val_accuracy: 0.1288
# Epoch 13/15
#  - 7s - loss: 2.2943 - accuracy: 0.1218 - val_loss: 2.2905 - val_accuracy: 0.1326
# Epoch 14/15
#  - 7s - loss: 2.2930 - accuracy: 0.1234 - val_loss: 2.2896 - val_accuracy: 0.1344
# Epoch 15/15
#  - 7s - loss: 2.2928 - accuracy: 0.1221 - val_loss: 2.2888 - val_accuracy: 0.1352
# Test loss: 2.2890845100402832, Test accuracy: 13.989999890327454
# [I 2020-05-03 23:54:50,105] Finished trial#3 resulted in value: 0.13989999890327454. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 8,540,938
# Trainable params: 8,540,938
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 13s - loss: 1.9763 - accuracy: 0.2890 - val_loss: 1.8833 - val_accuracy: 0.3070
# Epoch 2/15
#  - 13s - loss: 1.6964 - accuracy: 0.3954 - val_loss: 1.6547 - val_accuracy: 0.4194
# Epoch 3/15
#  - 13s - loss: 1.5702 - accuracy: 0.4405 - val_loss: 1.7021 - val_accuracy: 0.3868
# Epoch 4/15
#  - 13s - loss: 1.4649 - accuracy: 0.4816 - val_loss: 1.3955 - val_accuracy: 0.4948
# Epoch 5/15
#  - 13s - loss: 1.3762 - accuracy: 0.5096 - val_loss: 1.3857 - val_accuracy: 0.5130
# Epoch 6/15
#  - 13s - loss: 1.2886 - accuracy: 0.5412 - val_loss: 1.3485 - val_accuracy: 0.5172
# Epoch 7/15
#  - 12s - loss: 1.1999 - accuracy: 0.5752 - val_loss: 1.2322 - val_accuracy: 0.5640
# Epoch 8/15
#  - 14s - loss: 1.1240 - accuracy: 0.6041 - val_loss: 1.1683 - val_accuracy: 0.5892
# Epoch 9/15
#  - 15s - loss: 1.0474 - accuracy: 0.6305 - val_loss: 1.1338 - val_accuracy: 0.6068
# Epoch 10/15
#  - 16s - loss: 0.9718 - accuracy: 0.6574 - val_loss: 1.0316 - val_accuracy: 0.6330
# Epoch 11/15
#  - 16s - loss: 0.8976 - accuracy: 0.6818 - val_loss: 1.0560 - val_accuracy: 0.6314
# Epoch 12/15
#  - 15s - loss: 0.8253 - accuracy: 0.7074 - val_loss: 1.0429 - val_accuracy: 0.6370
# Epoch 13/15
#  - 15s - loss: 0.7454 - accuracy: 0.7380 - val_loss: 1.0384 - val_accuracy: 0.6372
# Epoch 14/15
#  - 15s - loss: 0.6708 - accuracy: 0.7654 - val_loss: 1.0018 - val_accuracy: 0.6614
# Epoch 15/15
#  - 15s - loss: 0.5921 - accuracy: 0.7932 - val_loss: 1.0398 - val_accuracy: 0.6600
# Test loss: 1.087831706428528, Test accuracy: 64.52000141143799
# [I 2020-05-03 23:58:24,518] Finished trial#4 resulted in value: 0.6452000141143799. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              67110912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              263168
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 68,021,482
# Trainable params: 68,021,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 28s - loss: 2.3032 - accuracy: 0.1014 - val_loss: 2.3026 - val_accuracy: 0.1066
# Epoch 2/15
#  - 28s - loss: 2.3024 - accuracy: 0.1024 - val_loss: 2.3017 - val_accuracy: 0.1080
# Epoch 3/15
#  - 28s - loss: 2.3018 - accuracy: 0.1048 - val_loss: 2.3009 - val_accuracy: 0.1100
# Epoch 4/15
#  - 27s - loss: 2.3012 - accuracy: 0.1092 - val_loss: 2.3001 - val_accuracy: 0.1136
# Epoch 5/15
#  - 28s - loss: 2.3005 - accuracy: 0.1116 - val_loss: 2.2993 - val_accuracy: 0.1268
# Epoch 6/15
#  - 27s - loss: 2.2999 - accuracy: 0.1179 - val_loss: 2.2985 - val_accuracy: 0.1436
# Epoch 7/15
#  - 27s - loss: 2.2993 - accuracy: 0.1219 - val_loss: 2.2977 - val_accuracy: 0.1502
# Epoch 8/15
#  - 27s - loss: 2.2987 - accuracy: 0.1216 - val_loss: 2.2968 - val_accuracy: 0.1490
# Epoch 9/15
#  - 28s - loss: 2.2978 - accuracy: 0.1243 - val_loss: 2.2959 - val_accuracy: 0.1462
# Epoch 10/15
#  - 27s - loss: 2.2971 - accuracy: 0.1270 - val_loss: 2.2950 - val_accuracy: 0.1428
# Epoch 11/15
#  - 28s - loss: 2.2964 - accuracy: 0.1300 - val_loss: 2.2940 - val_accuracy: 0.1384
# Epoch 12/15
#  - 27s - loss: 2.2957 - accuracy: 0.1289 - val_loss: 2.2931 - val_accuracy: 0.1382
# Epoch 13/15
#  - 27s - loss: 2.2948 - accuracy: 0.1320 - val_loss: 2.2920 - val_accuracy: 0.1380
# Epoch 14/15
#  - 28s - loss: 2.2939 - accuracy: 0.1335 - val_loss: 2.2909 - val_accuracy: 0.1394
# Epoch 15/15
#  - 28s - loss: 2.2929 - accuracy: 0.1345 - val_loss: 2.2897 - val_accuracy: 0.1394
# Test loss: 2.2899203727722166, Test accuracy: 13.770000636577606
# [I 2020-05-04 00:05:22,614] Finished trial#5 resulted in value: 0.13770000636577606. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              16778240
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 17,931,338
# Trainable params: 17,931,338
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 16s - loss: 2.2611 - accuracy: 0.1450 - val_loss: 2.1383 - val_accuracy: 0.2506
# Epoch 2/15
#  - 16s - loss: 1.9956 - accuracy: 0.2816 - val_loss: 1.8999 - val_accuracy: 0.3106
# Epoch 3/15
#  - 16s - loss: 1.8498 - accuracy: 0.3414 - val_loss: 1.7795 - val_accuracy: 0.3682
# Epoch 4/15
#  - 16s - loss: 1.7647 - accuracy: 0.3723 - val_loss: 1.7076 - val_accuracy: 0.3992
# Epoch 5/15
#  - 16s - loss: 1.7012 - accuracy: 0.3962 - val_loss: 1.6673 - val_accuracy: 0.4092
# Epoch 6/15
#  - 16s - loss: 1.6534 - accuracy: 0.4159 - val_loss: 1.6381 - val_accuracy: 0.4182
# Epoch 7/15
#  - 15s - loss: 1.6139 - accuracy: 0.4311 - val_loss: 1.5927 - val_accuracy: 0.4260
# Epoch 8/15
#  - 15s - loss: 1.5764 - accuracy: 0.4432 - val_loss: 1.5465 - val_accuracy: 0.4540
# Epoch 9/15
#  - 16s - loss: 1.5409 - accuracy: 0.4554 - val_loss: 1.5131 - val_accuracy: 0.4622
# Epoch 10/15
#  - 16s - loss: 1.5071 - accuracy: 0.4685 - val_loss: 1.4943 - val_accuracy: 0.4680
# Epoch 11/15
#  - 15s - loss: 1.4731 - accuracy: 0.4780 - val_loss: 1.4301 - val_accuracy: 0.4970
# Epoch 12/15
#  - 15s - loss: 1.4417 - accuracy: 0.4885 - val_loss: 1.4443 - val_accuracy: 0.4880
# Epoch 13/15
#  - 15s - loss: 1.4101 - accuracy: 0.5016 - val_loss: 1.4002 - val_accuracy: 0.5046
# Epoch 14/15
#  - 16s - loss: 1.3802 - accuracy: 0.5093 - val_loss: 1.3673 - val_accuracy: 0.5218
# Epoch 15/15
#  - 16s - loss: 1.3544 - accuracy: 0.5193 - val_loss: 1.3358 - val_accuracy: 0.5286
# Test loss: 1.323582130432129, Test accuracy: 53.130000829696655
# [I 2020-05-04 00:09:21,708] Finished trial#6 resulted in value: 0.5313000082969666. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              33555456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              264192
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 34,212,170
# Trainable params: 34,212,170
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 23s - loss: 2.3025 - accuracy: 0.0998 - val_loss: 2.3025 - val_accuracy: 0.0908
# Epoch 2/15
#  - 23s - loss: 2.3023 - accuracy: 0.1009 - val_loss: 2.3023 - val_accuracy: 0.0944
# Epoch 3/15
#  - 23s - loss: 2.3022 - accuracy: 0.1020 - val_loss: 2.3020 - val_accuracy: 0.0950
# Epoch 4/15
#  - 23s - loss: 2.3019 - accuracy: 0.1029 - val_loss: 2.3018 - val_accuracy: 0.0986
# Epoch 5/15
#  - 22s - loss: 2.3018 - accuracy: 0.1034 - val_loss: 2.3016 - val_accuracy: 0.1060
# Epoch 6/15
#  - 23s - loss: 2.3015 - accuracy: 0.1095 - val_loss: 2.3014 - val_accuracy: 0.1100
# Epoch 7/15
#  - 23s - loss: 2.3015 - accuracy: 0.1066 - val_loss: 2.3011 - val_accuracy: 0.1132
# Epoch 8/15
#  - 22s - loss: 2.3013 - accuracy: 0.1079 - val_loss: 2.3009 - val_accuracy: 0.1174
# Epoch 9/15
#  - 22s - loss: 2.3011 - accuracy: 0.1126 - val_loss: 2.3007 - val_accuracy: 0.1168
# Epoch 10/15
#  - 23s - loss: 2.3009 - accuracy: 0.1143 - val_loss: 2.3005 - val_accuracy: 0.1158
# Epoch 11/15
#  - 23s - loss: 2.3009 - accuracy: 0.1134 - val_loss: 2.3002 - val_accuracy: 0.1154
# Epoch 12/15
#  - 23s - loss: 2.3006 - accuracy: 0.1135 - val_loss: 2.3000 - val_accuracy: 0.1128
# Epoch 13/15
#  - 23s - loss: 2.3004 - accuracy: 0.1178 - val_loss: 2.2998 - val_accuracy: 0.1092
# Epoch 14/15
#  - 23s - loss: 2.3003 - accuracy: 0.1185 - val_loss: 2.2996 - val_accuracy: 0.1076
# Epoch 15/15
#  - 23s - loss: 2.2999 - accuracy: 0.1181 - val_loss: 2.2993 - val_accuracy: 0.1066
# Test loss: 2.299275394821167, Test accuracy: 10.779999941587448
# [I 2020-05-04 00:15:07,547] Finished trial#7 resulted in value: 0.10779999941587448. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4194432
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 4,308,330
# Trainable params: 4,308,330
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 14s - loss: 2.2758 - accuracy: 0.1382 - val_loss: 2.2101 - val_accuracy: 0.2194
# Epoch 2/15
#  - 14s - loss: 2.0504 - accuracy: 0.2708 - val_loss: 1.9519 - val_accuracy: 0.3002
# Epoch 3/15
#  - 13s - loss: 1.8847 - accuracy: 0.3284 - val_loss: 1.8288 - val_accuracy: 0.3398
# Epoch 4/15
#  - 13s - loss: 1.7827 - accuracy: 0.3681 - val_loss: 1.7494 - val_accuracy: 0.3846
# Epoch 5/15
#  - 14s - loss: 1.7041 - accuracy: 0.4001 - val_loss: 1.6689 - val_accuracy: 0.4020
# Epoch 6/15
#  - 13s - loss: 1.6398 - accuracy: 0.4215 - val_loss: 1.8316 - val_accuracy: 0.3486
# Epoch 7/15
#  - 13s - loss: 1.5897 - accuracy: 0.4350 - val_loss: 1.5522 - val_accuracy: 0.4526
# Epoch 8/15
#  - 13s - loss: 1.5445 - accuracy: 0.4532 - val_loss: 1.5141 - val_accuracy: 0.4674
# Epoch 9/15
#  - 14s - loss: 1.5032 - accuracy: 0.4663 - val_loss: 1.5319 - val_accuracy: 0.4594
# Epoch 10/15
#  - 13s - loss: 1.4676 - accuracy: 0.4798 - val_loss: 1.4247 - val_accuracy: 0.4922
# Epoch 11/15
#  - 13s - loss: 1.4295 - accuracy: 0.4943 - val_loss: 1.4347 - val_accuracy: 0.4930
# Epoch 12/15
#  - 14s - loss: 1.3933 - accuracy: 0.5081 - val_loss: 1.3950 - val_accuracy: 0.4990
# Epoch 13/15
#  - 13s - loss: 1.3617 - accuracy: 0.5173 - val_loss: 1.3865 - val_accuracy: 0.5124
# Epoch 14/15
#  - 13s - loss: 1.3256 - accuracy: 0.5310 - val_loss: 1.3095 - val_accuracy: 0.5350
# Epoch 15/15
#  - 14s - loss: 1.2907 - accuracy: 0.5458 - val_loss: 1.3494 - val_accuracy: 0.5140
# Test loss: 1.3449731580734252, Test accuracy: 51.819998025894165
# [I 2020-05-04 00:18:34,880] Finished trial#8 resulted in value: 0.5181999802589417. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               8389120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 8,561,738
# Trainable params: 8,561,738
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 12s - loss: 2.2899 - accuracy: 0.1354 - val_loss: 2.2696 - val_accuracy: 0.1806
# Epoch 2/15
#  - 12s - loss: 2.2518 - accuracy: 0.1851 - val_loss: 2.2190 - val_accuracy: 0.2264
# Epoch 3/15
#  - 12s - loss: 2.1915 - accuracy: 0.2150 - val_loss: 2.1428 - val_accuracy: 0.2548
# Epoch 4/15
#  - 12s - loss: 2.1187 - accuracy: 0.2405 - val_loss: 2.0609 - val_accuracy: 0.2916
# Epoch 5/15
#  - 12s - loss: 2.0408 - accuracy: 0.2745 - val_loss: 1.9882 - val_accuracy: 0.3126
# Epoch 6/15
#  - 11s - loss: 1.9781 - accuracy: 0.2962 - val_loss: 1.9400 - val_accuracy: 0.3222
# Epoch 7/15
#  - 12s - loss: 1.9374 - accuracy: 0.3138 - val_loss: 1.9012 - val_accuracy: 0.3396
# Epoch 8/15
#  - 12s - loss: 1.9056 - accuracy: 0.3252 - val_loss: 1.8772 - val_accuracy: 0.3412
# Epoch 9/15
#  - 12s - loss: 1.8772 - accuracy: 0.3351 - val_loss: 1.8533 - val_accuracy: 0.3554
# Epoch 10/15
#  - 12s - loss: 1.8545 - accuracy: 0.3453 - val_loss: 1.8249 - val_accuracy: 0.3638
# Epoch 11/15
#  - 12s - loss: 1.8305 - accuracy: 0.3545 - val_loss: 1.8063 - val_accuracy: 0.3692
# Epoch 12/15
#  - 12s - loss: 1.8069 - accuracy: 0.3635 - val_loss: 1.7820 - val_accuracy: 0.3798
# Epoch 13/15
#  - 12s - loss: 1.7907 - accuracy: 0.3707 - val_loss: 1.7752 - val_accuracy: 0.3794
# Epoch 14/15
#  - 12s - loss: 1.7683 - accuracy: 0.3767 - val_loss: 1.7469 - val_accuracy: 0.3848
# Epoch 15/15
#  - 12s - loss: 1.7472 - accuracy: 0.3798 - val_loss: 1.7331 - val_accuracy: 0.3902
# Test loss: 1.7098924842834473, Test accuracy: 39.93000090122223
# [I 2020-05-04 00:21:36,236] Finished trial#9 resulted in value: 0.3993000090122223. Current best value is 0.6452000141143799 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 2, 'n_units_1': 256, 'dropout_1': 0.2651290755506453, 'n_units_2': 256, 'dropout_2': 0.1775410164741598, 'lr': 0.004619709962483212}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4194560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 4,225,770
# Trainable params: 4,225,770
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 10s - loss: 1.9132 - accuracy: 0.3136 - val_loss: 1.7404 - val_accuracy: 0.3722
# Epoch 2/15
#  - 10s - loss: 1.5974 - accuracy: 0.4322 - val_loss: 1.5546 - val_accuracy: 0.4474
# Epoch 3/15
#  - 10s - loss: 1.4317 - accuracy: 0.4892 - val_loss: 1.3574 - val_accuracy: 0.5108
# Epoch 4/15
#  - 10s - loss: 1.3089 - accuracy: 0.5328 - val_loss: 1.3226 - val_accuracy: 0.5414
# Epoch 5/15
#  - 10s - loss: 1.1985 - accuracy: 0.5738 - val_loss: 1.2497 - val_accuracy: 0.5610
# Epoch 6/15
#  - 10s - loss: 1.1116 - accuracy: 0.6051 - val_loss: 1.2412 - val_accuracy: 0.5616
# Epoch 7/15
#  - 10s - loss: 1.0276 - accuracy: 0.6371 - val_loss: 1.0851 - val_accuracy: 0.6202
# Epoch 8/15
#  - 10s - loss: 0.9501 - accuracy: 0.6647 - val_loss: 1.1637 - val_accuracy: 0.5908
# Epoch 9/15
#  - 10s - loss: 0.8768 - accuracy: 0.6930 - val_loss: 1.0347 - val_accuracy: 0.6372
# Epoch 10/15
#  - 10s - loss: 0.8016 - accuracy: 0.7179 - val_loss: 1.0420 - val_accuracy: 0.6412
# Epoch 11/15
#  - 10s - loss: 0.7313 - accuracy: 0.7440 - val_loss: 1.0869 - val_accuracy: 0.6324
# Epoch 12/15
#  - 10s - loss: 0.6581 - accuracy: 0.7694 - val_loss: 0.9751 - val_accuracy: 0.6664
# Epoch 13/15
#  - 10s - loss: 0.5909 - accuracy: 0.7905 - val_loss: 0.9419 - val_accuracy: 0.6804
# Epoch 14/15
#  - 10s - loss: 0.5247 - accuracy: 0.8147 - val_loss: 0.9876 - val_accuracy: 0.6828
# Epoch 15/15
#  - 10s - loss: 0.4657 - accuracy: 0.8355 - val_loss: 1.0785 - val_accuracy: 0.6608
# Test loss: 1.1375937591552734, Test accuracy: 65.39000272750854
# [I 2020-05-04 00:24:10,793] Finished trial#10 resulted in value: 0.6539000272750854. Current best value is 0.6539000272750854 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 64, 'n_layers': 1, 'n_units_1': 256, 'dropout_1': 0.28198672171528877, 'lr': 0.007922519892128648}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 8,438,570
# Trainable params: 8,438,570
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 12s - loss: 1.9107 - accuracy: 0.3144 - val_loss: 1.7091 - val_accuracy: 0.3822
# Epoch 2/15
#  - 12s - loss: 1.5892 - accuracy: 0.4364 - val_loss: 1.4681 - val_accuracy: 0.4740
# Epoch 3/15
#  - 12s - loss: 1.3984 - accuracy: 0.5028 - val_loss: 1.6935 - val_accuracy: 0.4324
# Epoch 4/15
#  - 12s - loss: 1.2587 - accuracy: 0.5552 - val_loss: 1.3527 - val_accuracy: 0.5276
# Epoch 5/15
#  - 12s - loss: 1.1471 - accuracy: 0.5927 - val_loss: 1.1248 - val_accuracy: 0.6044
# Epoch 6/15
#  - 12s - loss: 1.0490 - accuracy: 0.6282 - val_loss: 1.0677 - val_accuracy: 0.6248
# Epoch 7/15
#  - 12s - loss: 0.9566 - accuracy: 0.6615 - val_loss: 0.9954 - val_accuracy: 0.6458
# Epoch 8/15
#  - 12s - loss: 0.8658 - accuracy: 0.6960 - val_loss: 1.0341 - val_accuracy: 0.6396
# Epoch 9/15
#  - 12s - loss: 0.7808 - accuracy: 0.7233 - val_loss: 1.0124 - val_accuracy: 0.6502
# Epoch 10/15
#  - 12s - loss: 0.6908 - accuracy: 0.7577 - val_loss: 0.9662 - val_accuracy: 0.6714
# Epoch 11/15
#  - 12s - loss: 0.6070 - accuracy: 0.7862 - val_loss: 0.9851 - val_accuracy: 0.6670
# Epoch 12/15
#  - 12s - loss: 0.5252 - accuracy: 0.8142 - val_loss: 0.9489 - val_accuracy: 0.6938
# Epoch 13/15
#  - 12s - loss: 0.4474 - accuracy: 0.8429 - val_loss: 1.0390 - val_accuracy: 0.6766
# Epoch 14/15
#  - 12s - loss: 0.3759 - accuracy: 0.8686 - val_loss: 1.0038 - val_accuracy: 0.7040
# Epoch 15/15
#  - 12s - loss: 0.3171 - accuracy: 0.8892 - val_loss: 1.1098 - val_accuracy: 0.6784
# Test loss: 1.1873188982009888, Test accuracy: 67.39000082015991
# [I 2020-05-04 00:27:15,841] Finished trial#11 resulted in value: 0.6739000082015991. Current best value is 0.6739000082015991 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 256, 'dropout_1': 0.29435870031350403, 'lr': 0.009697292162171462}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4194560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 4,225,770
# Trainable params: 4,225,770
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 10s - loss: 1.9324 - accuracy: 0.3030 - val_loss: 1.7827 - val_accuracy: 0.3500
# Epoch 2/15
#  - 10s - loss: 1.6146 - accuracy: 0.4236 - val_loss: 1.5198 - val_accuracy: 0.4468
# Epoch 3/15
#  - 10s - loss: 1.4376 - accuracy: 0.4835 - val_loss: 1.4497 - val_accuracy: 0.4640
# Epoch 4/15
#  - 10s - loss: 1.3104 - accuracy: 0.5338 - val_loss: 1.2340 - val_accuracy: 0.5552
# Epoch 5/15
#  - 10s - loss: 1.2053 - accuracy: 0.5708 - val_loss: 1.2544 - val_accuracy: 0.5628
# Epoch 6/15
#  - 10s - loss: 1.1150 - accuracy: 0.6051 - val_loss: 1.1186 - val_accuracy: 0.6034
# Epoch 7/15
#  - 10s - loss: 1.0328 - accuracy: 0.6354 - val_loss: 1.1276 - val_accuracy: 0.6028
# Epoch 8/15
#  - 10s - loss: 0.9526 - accuracy: 0.6635 - val_loss: 1.0344 - val_accuracy: 0.6398
# Epoch 9/15
#  - 10s - loss: 0.8748 - accuracy: 0.6927 - val_loss: 1.0283 - val_accuracy: 0.6448
# Epoch 10/15
#  - 10s - loss: 0.7976 - accuracy: 0.7179 - val_loss: 0.9896 - val_accuracy: 0.6542
# Epoch 11/15
#  - 10s - loss: 0.7189 - accuracy: 0.7470 - val_loss: 0.9625 - val_accuracy: 0.6706
# Epoch 12/15
#  - 10s - loss: 0.6438 - accuracy: 0.7741 - val_loss: 1.0155 - val_accuracy: 0.6602
# Epoch 13/15
#  - 10s - loss: 0.5697 - accuracy: 0.8001 - val_loss: 1.0769 - val_accuracy: 0.6504
# Epoch 14/15
#  - 10s - loss: 0.4989 - accuracy: 0.8256 - val_loss: 1.0265 - val_accuracy: 0.6744
# Epoch 15/15
#  - 10s - loss: 0.4342 - accuracy: 0.8462 - val_loss: 1.2481 - val_accuracy: 0.6362
# Test loss: 1.2650369523048401, Test accuracy: 62.43000030517578
# [I 2020-05-04 00:29:51,199] Finished trial#12 resulted in value: 0.6243000030517578. Current best value is 0.6739000082015991 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 256, 'dropout_1': 0.29435870031350403, 'lr': 0.009697292162171462}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4194560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 4,225,770
# Trainable params: 4,225,770
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 11s - loss: 1.9139 - accuracy: 0.3130 - val_loss: 1.7737 - val_accuracy: 0.3706
# Epoch 2/15
#  - 10s - loss: 1.6648 - accuracy: 0.4115 - val_loss: 1.5543 - val_accuracy: 0.4396
# Epoch 3/15
#  - 10s - loss: 1.4948 - accuracy: 0.4683 - val_loss: 1.5232 - val_accuracy: 0.4538
# Epoch 4/15
#  - 10s - loss: 1.3707 - accuracy: 0.5146 - val_loss: 1.2992 - val_accuracy: 0.5376
# ...
# Total params: 8,484,682
# Trainable params: 8,484,682
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 26s - loss: 2.0018 - accuracy: 0.2777 - val_loss: 1.7991 - val_accuracy: 0.3764
# Epoch 2/15
#  - 29s - loss: 1.7205 - accuracy: 0.3887 - val_loss: 1.6663 - val_accuracy: 0.4128
# Epoch 3/15
#  - 25s - loss: 1.5574 - accuracy: 0.4463 - val_loss: 1.5230 - val_accuracy: 0.4554
# Epoch 4/15
#  - 25s - loss: 1.4532 - accuracy: 0.4833 - val_loss: 1.4018 - val_accuracy: 0.5054
# Epoch 5/15
#  - 26s - loss: 1.3685 - accuracy: 0.5146 - val_loss: 1.4379 - val_accuracy: 0.4824
# Epoch 6/15
#  - 24s - loss: 1.2917 - accuracy: 0.5391 - val_loss: 1.2595 - val_accuracy: 0.5504
# Epoch 7/15
#  - 27s - loss: 1.2239 - accuracy: 0.5658 - val_loss: 1.2309 - val_accuracy: 0.5692
# Epoch 8/15
#  - 25s - loss: 1.1624 - accuracy: 0.5894 - val_loss: 1.1509 - val_accuracy: 0.5924
# Epoch 9/15
#  - 25s - loss: 1.1063 - accuracy: 0.6078 - val_loss: 1.1369 - val_accuracy: 0.6044
# Epoch 10/15
#  - 27s - loss: 1.0524 - accuracy: 0.6289 - val_loss: 1.1192 - val_accuracy: 0.6056
# Epoch 11/15
#  - 24s - loss: 0.9987 - accuracy: 0.6476 - val_loss: 1.0950 - val_accuracy: 0.6152
# Epoch 12/15
#  - 28s - loss: 0.9480 - accuracy: 0.6664 - val_loss: 1.0282 - val_accuracy: 0.6380
# Epoch 13/15
#  - 25s - loss: 0.8980 - accuracy: 0.6848 - val_loss: 1.0776 - val_accuracy: 0.6168
# Epoch 14/15
#  - 25s - loss: 0.8467 - accuracy: 0.7022 - val_loss: 0.9935 - val_accuracy: 0.6528
# Epoch 15/15
#  - 27s - loss: 0.7996 - accuracy: 0.7213 - val_loss: 1.0660 - val_accuracy: 0.6352
# Test loss: 1.0998026205062865, Test accuracy: 62.40000128746033
# [I 2020-05-04 04:05:55,620] Finished trial#45 resulted in value: 0.6240000128746033. Current best value is 0.6879000067710876 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 1024, 'dropout_1': 0.2981457219491899, 'lr': 0.009606588302704272}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 16,840,106
# Trainable params: 16,840,106
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 32s - loss: 1.9107 - accuracy: 0.3122 - val_loss: 1.8139 - val_accuracy: 0.3570
# Epoch 2/15
#  - 29s - loss: 1.6150 - accuracy: 0.4314 - val_loss: 1.6329 - val_accuracy: 0.4180
# Epoch 3/15
#  - 28s - loss: 1.4491 - accuracy: 0.4857 - val_loss: 1.4617 - val_accuracy: 0.4682
# Epoch 4/15
#  - 31s - loss: 1.2933 - accuracy: 0.5412 - val_loss: 1.2243 - val_accuracy: 0.5656
# Epoch 5/15
#  - 29s - loss: 1.1637 - accuracy: 0.5879 - val_loss: 1.2242 - val_accuracy: 0.5662
# Epoch 6/15
#  - 29s - loss: 1.0539 - accuracy: 0.6300 - val_loss: 1.1646 - val_accuracy: 0.5940
# Epoch 7/15
#  - 32s - loss: 0.9511 - accuracy: 0.6655 - val_loss: 1.0975 - val_accuracy: 0.6134
# Epoch 8/15
#  - 28s - loss: 0.8463 - accuracy: 0.7036 - val_loss: 1.1278 - val_accuracy: 0.6170
# Epoch 9/15
#  - 29s - loss: 0.7448 - accuracy: 0.7410 - val_loss: 1.0150 - val_accuracy: 0.6546
# Epoch 10/15
#  - 30s - loss: 0.6391 - accuracy: 0.7782 - val_loss: 1.1130 - val_accuracy: 0.6368
# Epoch 11/15
#  - 30s - loss: 0.5422 - accuracy: 0.8138 - val_loss: 1.0579 - val_accuracy: 0.6536
# Epoch 12/15
#  - 29s - loss: 0.4360 - accuracy: 0.8511 - val_loss: 1.1749 - val_accuracy: 0.6312
# Epoch 13/15
#  - 29s - loss: 0.3432 - accuracy: 0.8822 - val_loss: 1.0800 - val_accuracy: 0.6688
# Epoch 14/15
#  - 32s - loss: 0.2619 - accuracy: 0.9121 - val_loss: 1.5937 - val_accuracy: 0.6104
# Epoch 15/15
#  - 29s - loss: 0.1976 - accuracy: 0.9334 - val_loss: 1.2732 - val_accuracy: 0.6774
# Test loss: 1.3237227124214173, Test accuracy: 66.28999710083008
# [I 2020-05-04 04:13:27,683] Finished trial#46 resulted in value: 0.6628999710083008. Current best value is 0.6879000067710876 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 1024, 'dropout_1': 0.2981457219491899, 'lr': 0.009606588302704272}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2097280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 2,127,210
# Trainable params: 2,127,210
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 18s - loss: 2.3032 - accuracy: 0.1073 - val_loss: 2.3014 - val_accuracy: 0.1126
# Epoch 2/15
#  - 21s - loss: 2.3005 - accuracy: 0.1125 - val_loss: 2.2987 - val_accuracy: 0.1186
# Epoch 3/15
#  - 18s - loss: 2.2978 - accuracy: 0.1188 - val_loss: 2.2961 - val_accuracy: 0.1264
# Epoch 4/15
#  - 21s - loss: 2.2958 - accuracy: 0.1260 - val_loss: 2.2938 - val_accuracy: 0.1390
# Epoch 5/15
#  - 18s - loss: 2.2935 - accuracy: 0.1291 - val_loss: 2.2915 - val_accuracy: 0.1516
# Epoch 6/15
#  - 20s - loss: 2.2912 - accuracy: 0.1368 - val_loss: 2.2893 - val_accuracy: 0.1478
# Epoch 7/15
#  - 20s - loss: 2.2887 - accuracy: 0.1422 - val_loss: 2.2870 - val_accuracy: 0.1450
# Epoch 8/15
#  - 18s - loss: 2.2868 - accuracy: 0.1409 - val_loss: 2.2846 - val_accuracy: 0.1408
# Epoch 9/15
#  - 22s - loss: 2.2843 - accuracy: 0.1425 - val_loss: 2.2822 - val_accuracy: 0.1420
# Epoch 10/15
#  - 18s - loss: 2.2822 - accuracy: 0.1420 - val_loss: 2.2797 - val_accuracy: 0.1422
# Epoch 11/15
#  - 21s - loss: 2.2795 - accuracy: 0.1459 - val_loss: 2.2770 - val_accuracy: 0.1444
# Epoch 12/15
#  - 18s - loss: 2.2765 - accuracy: 0.1480 - val_loss: 2.2742 - val_accuracy: 0.1474
# Epoch 13/15
#  - 22s - loss: 2.2739 - accuracy: 0.1479 - val_loss: 2.2711 - val_accuracy: 0.1514
# Epoch 14/15
#  - 18s - loss: 2.2709 - accuracy: 0.1526 - val_loss: 2.2679 - val_accuracy: 0.1580
# Epoch 15/15
#  - 18s - loss: 2.2679 - accuracy: 0.1556 - val_loss: 2.2644 - val_accuracy: 0.1650
# Test loss: 2.265306555175781, Test accuracy: 15.899999439716339
# [I 2020-05-04 04:18:23,473] Finished trial#47 resulted in value: 0.1589999943971634. Current best value is 0.6879000067710876 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 1024, 'dropout_1': 0.2981457219491899, 'lr': 0.009606588302704272}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 8,438,570
# Trainable params: 8,438,570
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 24s - loss: 1.8727 - accuracy: 0.3278 - val_loss: 2.1951 - val_accuracy: 0.2528
# Epoch 2/15
#  - 22s - loss: 1.5274 - accuracy: 0.4540 - val_loss: 1.4914 - val_accuracy: 0.4648
# Epoch 3/15
#  - 24s - loss: 1.3723 - accuracy: 0.5069 - val_loss: 1.2873 - val_accuracy: 0.5404
# Epoch 4/15
#  - 22s - loss: 1.2445 - accuracy: 0.5563 - val_loss: 1.2343 - val_accuracy: 0.5658
# Epoch 5/15
#  - 22s - loss: 1.1317 - accuracy: 0.5994 - val_loss: 1.1209 - val_accuracy: 0.6032
# Epoch 6/15
#  - 24s - loss: 1.0285 - accuracy: 0.6353 - val_loss: 1.1408 - val_accuracy: 0.5938
# Epoch 7/15
#  - 22s - loss: 0.9269 - accuracy: 0.6750 - val_loss: 1.0137 - val_accuracy: 0.6478
# Epoch 8/15
#  - 24s - loss: 0.8329 - accuracy: 0.7061 - val_loss: 0.9323 - val_accuracy: 0.6764
# Epoch 9/15
#  - 22s - loss: 0.7419 - accuracy: 0.7396 - val_loss: 0.9769 - val_accuracy: 0.6590
# Epoch 10/15
#  - 24s - loss: 0.6525 - accuracy: 0.7712 - val_loss: 0.9357 - val_accuracy: 0.6838
# Epoch 11/15
#  - 22s - loss: 0.5679 - accuracy: 0.8007 - val_loss: 0.9666 - val_accuracy: 0.6780
# Epoch 12/15
#  - 22s - loss: 0.4871 - accuracy: 0.8290 - val_loss: 1.0340 - val_accuracy: 0.6774
# Epoch 13/15
#  - 25s - loss: 0.4095 - accuracy: 0.8581 - val_loss: 0.9605 - val_accuracy: 0.6984
# Epoch 14/15
#  - 22s - loss: 0.3383 - accuracy: 0.8823 - val_loss: 1.0451 - val_accuracy: 0.6910
# Epoch 15/15
#  - 24s - loss: 0.2788 - accuracy: 0.9034 - val_loss: 1.0822 - val_accuracy: 0.6984
# Test loss: 1.1331200716972352, Test accuracy: 68.27999949455261
# [I 2020-05-04 04:24:13,130] Finished trial#48 resulted in value: 0.6827999949455261. Current best value is 0.6879000067710876 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 1024, 'dropout_1': 0.2981457219491899, 'lr': 0.009606588302704272}.
# Not using data augmentation.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              526336
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 13,179,178
# Trainable params: 13,179,178
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 31s - loss: 2.3015 - accuracy: 0.1043 - val_loss: 2.2989 - val_accuracy: 0.1366
# Epoch 2/15
#  - 28s - loss: 2.2974 - accuracy: 0.1257 - val_loss: 2.2924 - val_accuracy: 0.1252
# Epoch 3/15
#  - 28s - loss: 2.2896 - accuracy: 0.1287 - val_loss: 2.2777 - val_accuracy: 0.1274
# Epoch 4/15
#  - 31s - loss: 2.2691 - accuracy: 0.1422 - val_loss: 2.2384 - val_accuracy: 0.1780
# Epoch 5/15
#  - 28s - loss: 2.2133 - accuracy: 0.1816 - val_loss: 2.1355 - val_accuracy: 0.2390
# Epoch 6/15
#  - 28s - loss: 2.1014 - accuracy: 0.2268 - val_loss: 2.0245 - val_accuracy: 0.2612
# Epoch 7/15
#  - 30s - loss: 2.0192 - accuracy: 0.2587 - val_loss: 1.9652 - val_accuracy: 0.2784
# Epoch 8/15
#  - 30s - loss: 1.9712 - accuracy: 0.2812 - val_loss: 1.9234 - val_accuracy: 0.3008
# Epoch 9/15
#  - 28s - loss: 1.9295 - accuracy: 0.3022 - val_loss: 1.8981 - val_accuracy: 0.3174
# Epoch 10/15
#  - 28s - loss: 1.8928 - accuracy: 0.3194 - val_loss: 1.8449 - val_accuracy: 0.3428
# Epoch 11/15
#  - 31s - loss: 1.8538 - accuracy: 0.3376 - val_loss: 1.8186 - val_accuracy: 0.3564
# Epoch 12/15
#  - 28s - loss: 1.8224 - accuracy: 0.3498 - val_loss: 1.7852 - val_accuracy: 0.3650
# Epoch 13/15
#  - 28s - loss: 1.7897 - accuracy: 0.3585 - val_loss: 1.7983 - val_accuracy: 0.3532
# Epoch 14/15
#  - 31s - loss: 1.7578 - accuracy: 0.3695 - val_loss: 1.7183 - val_accuracy: 0.3854
# Epoch 15/15
#  - 29s - loss: 1.7313 - accuracy: 0.3808 - val_loss: 1.6877 - val_accuracy: 0.3972
# Test loss: 1.6603497871398927, Test accuracy: 40.950000286102295
# [I 2020-05-04 04:31:35,293] Finished trial#49 resulted in value: 0.40950000286102295. Current best value is 0.6879000067710876 with parameters: {'filters': 32, 'n_cnn': 2, 'n_filters_1': 32, 'n_filters_2': 128, 'n_layers': 1, 'n_units_1': 1024, 'dropout_1': 0.2981457219491899, 'lr': 0.009606588302704272}.
# Study statistics:
#   Number of finished trials:  50
#   Number of pruned trials:  0
#   Number of complete trials:  50
# Best trial:
#   Value:  0.6879000067710876
#   Params:
#     filters: 32
#     n_cnn: 2
#     n_filters_1: 32
#     n_filters_2: 128
#     n_layers: 1
#     n_units_1: 1024
#     dropout_1: 0.2981457219491899
#     lr: 0.009606588302704272

# %%
with open("Optuna_result_CIFAR10_dict.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["Results"])
    for trial in study.trials:
        writer.writerow([trial.value])

# %%
for i in range(50):
    print(study.trials[i].value)
# Out:
# 0.4357999861240387
# 0.14900000393390656
# 0.6452000141143799
# 0.13989999890327454
# 0.6452000141143799
# 0.13770000636577606
# 0.5313000082969666
# 0.10779999941587448
# 0.5181999802589417
# 0.3993000090122223
# 0.6539000272750854
# 0.6739000082015991
# 0.6243000030517578
# 0.666100025177002
# 0.6114000082015991
# 0.5285000205039978
# 0.6764000058174133
# 0.4032000005245209
# 0.5999000072479248
# 0.30730000138282776
# 0.3675999939441681
# 0.6840000152587891
# 0.6858999729156494
# 0.6550999879837036
# 0.6801999807357788
# 0.5613999962806702
# 0.6633999943733215
# 0.6790000200271606
# 0.6646000146865845
# 0.4528000056743622
# 0.5889000296592712
# 0.6592000126838684
# 0.6636999845504761
# 0.630299985408783
# 0.2101999968290329
# 0.6226999759674072
# 0.5734999775886536
# 0.6324999928474426
# 0.6498000025749207
# 0.534600019454956
# 0.6858000159263611
# 0.6718999743461609
# 0.6879000067710876
# 0.6812999844551086
# 0.6550999879837036
# 0.6240000128746033
# 0.6628999710083008
# 0.1589999943971634
# 0.6827999949455261
# 0.40950000286102295
